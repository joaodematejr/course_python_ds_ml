# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
sns.countplot(x='sex', data=tips)
sns.despine(left=True)

# %%
sns.set_context('poster', font_scale=2)
sns.lmplot(x='total_bill', y='tip', data=tips, size=10, aspect=1)
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_context('poster', font_scale=1)
sns.lmplot(x='total_bill', y='tip', data=tips, size=10, aspect=1, hue='sex', palette='viridis')
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#https://matplotlib.org/tutorials/colors/colormaps.html
